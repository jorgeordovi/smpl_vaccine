# %%
import numpy as np

# %%
import pandas as pd

# %%
data_location = "Documents/GitHub/smpl_vaccine/dataset_total_vacunas.csv"

data = pd.read_csv(data_location)

data
# Out:
#      FECHA_ADMINISTRACION GRUPO_ETARIO GENERO      VACUNA      TIPO_EFECTOR  \
# 0               22FEB2021   30 o menos      F  Covishield           Publico
# 1               22FEB2021   30 o menos      F     Sputnik           Privado
# 2               22FEB2021   30 o menos      F     Sputnik           Publico
# 3               22FEB2021   30 o menos      F     Sputnik  Publico nacional
# 4               22FEB2021   30 o menos      M  Covishield           Publico
# ...                   ...          ...    ...         ...               ...
# 1860            17FEB2021      61 a 70      F     Sputnik           Privado
# 1861            17FEB2021      61 a 70      F     Sputnik           Publico
# 1862            17FEB2021      61 a 70      F     Sputnik  Publico nacional
# 1863            17FEB2021      61 a 70      M     Sputnik           Privado
# 1864            17FEB2021      61 a 70      M     Sputnik           Publico
#
#       DOSIS_1  DOSIS_2
# 0          13        0
# ...
